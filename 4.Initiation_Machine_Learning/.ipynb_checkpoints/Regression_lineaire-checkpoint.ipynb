# %%
# On importe les librairies dont on aura besoin pour ce tp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# On charge le dataset
house_data = pd.read_csv('house.csv')

# On affiche le nuage de points dont on dispose
plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)
plt.show()

# %%
#d'après la visualisation, on peut se dire que le montant du loyer dépend de manière 
#linéaire de la surface du logement. On peut donc émettre une hypothèse de 
#modélisation qui est que le phénomène possède la forme d'une droite.

# %%
#on peut voir que lorsque la surface devient un peu trop grande, les données 
#semblent devenir moins modélisables facilement, il y a plus de variabilité. 
#On va considérer pour l'instant résoudre le problème de prédiction pour 
#les loyers inférieurs à 10,000€
house_data = house_data[house_data['loyer'] < 10000]

# %%
#La régression linéaire s’appuie sur l’hypothèse que les données proviennent 
#d’un phénomène qui a la forme d'une droite, c’est-à-dire qu’il existe 
#une relation linéaire entre l’entrée (les observations) et la sortie (les prédictions)

# %%
#Pour effectuer une régression linéaire, on doit ensuite choisir une fonction de perte
#on va donc chercher à trouver le θ qui minimise cette fonction de perte (qu’on note E)
#Solution de la minimisation θ̂ =(XTX)−1XTy
#On cherche à minimiser la fonction E en fonction de theta. 
#La fonction est convexe (c’est une somme de carrés), donc elle possède 
#un optimum global (en l’occurrence un minimum), qui se trouve à l’endroit où la dérivée 
#première en theta est nulle.

# %%
#Il existe une solution exacte dans ce cas précis
#Mais on peut aussi utiliser un algorithme appelé descente de gradient 
#pour trouver une approximation de la solution. C'est en particulier utile lorsque l'on a 
#beaucoup de données d'exemple

# %%
# On décompose le dataset et on le transforme en matrices pour pouvoir effectuer notre calcul
X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['loyer']).T

# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

print(theta)
#On trouve donc la valeur numérique de θ pour nos données :
# Out:
# [[266.45460292]
#  [ 30.66119596]]

# %%
#Notre modèle final qui colle bien aux données sera donc dans notre cas (approximativement) :
#loyer=30.7×surface+266.4

# %%
#On peut représenter graphiquement la droite qu'on a trouvée, pour vérifier qu'elle 
#colle bien aux données :
plt.xlabel('Surface')
plt.ylabel('Loyer')

plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)

# On affiche la droite entre 0 et 250
plt.plot([0,250], [theta.item(0),theta.item(0) + 250 * theta.item(1)], linestyle='--', c='#000000')

plt.show()

# %%
#Maintenant qu’on a notre paramètre θ, c’est-à-dire qu’on a trouvé la droite qui colle le mieux à 
#nos données d’entraînement, on peut effectuer des prédictions sur de nouvelles données
#Par exemple, si on l’applique pour une surface de 35 mètres carrés :
theta.item(0) + theta.item(1) * 35
# Out:
# 1339.5964615602245
